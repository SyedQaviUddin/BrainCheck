# %%
joblib.dump(clf, 'backend/model.pkl')
print('Model saved as backend/model.pkl')
# Out:
# Model saved as backend/model.pkl

# %%
y_pred = clf.predict(X_test)
print(classification_report(y_test, y_pred))

# Cross-validation (optional)
scores = cross_val_score(clf, X, y, cv=3)
print(f'Cross-validation scores: {scores}')
# Out:
# c:\Users\sqavi\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\sqavi\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1706: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\sqavi\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
print(f'Train size: {len(X_train)}, Test size: {len(X_test)}')
# Out:
# Train size: 4, Test size: 2

# %%
# Select features and target
X = df[['avg_dwell_time', 'avg_flight_time', 'backspace_count', 'total_time']]
y = df['label']

# %%
# Check basic info and class distribution
print(df.info())
print(df['label'].value_counts())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   user_id          6 non-null      object
#  1   avg_dwell_time   6 non-null      int64
#  2   avg_flight_time  6 non-null      int64
#  3   backspace_count  6 non-null      int64
#  4   total_time       6 non-null      float64
#  5   label            6 non-null      object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 416.0+ bytes
# None
# label
# alert        3
# fatigued     2
# fatigued     1
# Name: count, dtype: int64

# %%
# Load the sample keystroke dataset
df = pd.read_csv('dataset.csv')
df.head()
# Out:
#   user_id  avg_dwell_time  avg_flight_time  backspace_count  total_time  \
# 0    u001             180               90                2        15.4
# 1    u002             250              160                7        22.1
# 2    u003             170               80                1        14.2
# 3    u004             260              170                8        23.5
# 4    u005             190              100                3        16.0
#
#       label
# 0     alert
# 1  fatigued
# 2     alert
# 3  fatigued
# 4     alert

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import classification_report
import joblib
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 from sklearn.ensemble import RandomForestClassifier
#       3 from sklearn.model_selection import train_test_split, cross_val_score
#       4 from sklearn.metrics import classification_report
#
# File c:\Users\sqavi\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\__init__.py:73
#      62 # `_distributor_init` allows distributors to run custom init code.
#      63 # For instance, for the Windows wheel, this is used to pre-load the
#      64 # vcomp shared library runtime for OpenMP embedded in the sklearn/.libs
#    (...)
#      67 # later is linked to the OpenMP runtime to make it possible to introspect
#      68 # it and importing it first would fail if the OpenMP dll cannot be found.
#      69 from . import (  # noqa: F401 E402
# ...

# %%
# BrainCheck Model Training
